-- %% [markdown]
-- # [2Konov_DB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [2Konov_DB]    Script Date: 17.11.2023 18:59:31 ******/
CREATE DATABASE [2Konov_DB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'2Konov_DB', FILENAME = N'C:\Users\dimak\2Konov_DB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'2Konov_DB_log', FILENAME = N'C:\Users\dimak\2Konov_DB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [2Konov_DB] SET COMPATIBILITY_LEVEL = 130
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [2Konov_DB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [2Konov_DB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [2Konov_DB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [2Konov_DB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [2Konov_DB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [2Konov_DB] SET ARITHABORT OFF 
GO
ALTER DATABASE [2Konov_DB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [2Konov_DB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [2Konov_DB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [2Konov_DB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [2Konov_DB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [2Konov_DB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [2Konov_DB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [2Konov_DB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [2Konov_DB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [2Konov_DB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [2Konov_DB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [2Konov_DB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [2Konov_DB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [2Konov_DB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [2Konov_DB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [2Konov_DB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [2Konov_DB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [2Konov_DB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [2Konov_DB] SET  MULTI_USER 
GO
ALTER DATABASE [2Konov_DB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [2Konov_DB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [2Konov_DB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [2Konov_DB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [2Konov_DB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [2Konov_DB] SET QUERY_STORE = OFF
GO
USE [2Konov_DB]
GO
ALTER DATABASE SCOPED CONFIGURATION SET LEGACY_CARDINALITY_ESTIMATION = OFF;
GO
ALTER DATABASE SCOPED CONFIGURATION SET MAXDOP = 0;
GO
ALTER DATABASE SCOPED CONFIGURATION SET PARAMETER_SNIFFING = ON;
GO
ALTER DATABASE SCOPED CONFIGURATION SET QUERY_OPTIMIZER_HOTFIXES = OFF;
GO

-- %% [markdown]
-- # [dbo].[Country]

-- %%
USE [2Konov_DB]
GO

-- %%
/****** Object:  Table [dbo].[Country]    Script Date: 17.11.2023 18:59:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Country](
	[CountryName] [nvarchar](50) NOT NULL,
	[Continent] [nvarchar](50) NOT NULL,
	[Currency] [nvarchar](50) NULL,
 CONSTRAINT [PK_Country] PRIMARY KEY CLUSTERED 
(
	[CountryName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Department]

-- %%
/****** Object:  Table [dbo].[Department]    Script Date: 17.11.2023 18:59:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Department](
	[DeptName] [nvarchar](50) NOT NULL,
	[CountryName] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Department] PRIMARY KEY CLUSTERED 
(
	[DeptName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Employee]

-- %%
/****** Object:  Table [dbo].[Employee]    Script Date: 17.11.2023 18:59:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employee](
	[EmpName] [nvarchar](50) NOT NULL,
	[DeptName] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Employee] PRIMARY KEY CLUSTERED 
(
	[EmpName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Folder]

-- %%
/****** Object:  Table [dbo].[Folder]    Script Date: 17.11.2023 18:59:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Folder](
	[FolderName] [nvarchar](50) NOT NULL,
	[EmpName] [nvarchar](50) NOT NULL,
	[AccessType] [nvarchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Country]

-- %%
INSERT [dbo].[Country] ([CountryName], [Continent], [Currency]) VALUES (N'Америка', N'Теплый', N'Даллары')
INSERT [dbo].[Country] ([CountryName], [Continent], [Currency]) VALUES (N'Африка', N'Южный', N'Русская')
INSERT [dbo].[Country] ([CountryName], [Continent], [Currency]) VALUES (N'Нероссия', N'Холодный', N'Русская')
GO

-- %% [markdown]
-- # [dbo].[Department]

-- %%
INSERT [dbo].[Department] ([DeptName], [CountryName]) VALUES (N'ФСБ', N'Африка')
GO

-- %% [markdown]
-- # [dbo].[Employee]

-- %%
INSERT [dbo].[Employee] ([EmpName], [DeptName]) VALUES (N'Полицейский', N'ФСБ')
GO

-- %% [markdown]
-- # [dbo].[Folder]

-- %%
INSERT [dbo].[Folder] ([FolderName], [EmpName], [AccessType]) VALUES (N'Папка1', N'Полицейский', N'Нет доступа')
GO

-- %% [markdown]
-- # [FK_Department_Country]

-- %%
ALTER TABLE [dbo].[Department]  WITH CHECK ADD  CONSTRAINT [FK_Department_Country] FOREIGN KEY([CountryName])
REFERENCES [dbo].[Country] ([CountryName])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Department] CHECK CONSTRAINT [FK_Department_Country]
GO

-- %% [markdown]
-- # [FK_Employee_Department]

-- %%
ALTER TABLE [dbo].[Employee]  WITH CHECK ADD  CONSTRAINT [FK_Employee_Department] FOREIGN KEY([DeptName])
REFERENCES [dbo].[Department] ([DeptName])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Employee] CHECK CONSTRAINT [FK_Employee_Department]
GO

-- %% [markdown]
-- # [FK_Folder_Employee]

-- %%
ALTER TABLE [dbo].[Folder]  WITH CHECK ADD  CONSTRAINT [FK_Folder_Employee] FOREIGN KEY([EmpName])
REFERENCES [dbo].[Employee] ([EmpName])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Folder] CHECK CONSTRAINT [FK_Folder_Employee]
GO

-- %% [markdown]
-- # [2Konov_DB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [2Konov_DB] SET  READ_WRITE 
GO
